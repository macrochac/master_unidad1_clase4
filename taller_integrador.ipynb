# %% [markdown]
# ## Taller integrador

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

#print(pd.__version__)

df = pd.read_csv("estudiantes2026.csv")
df
# Out:
#                nombre  edad            ciudad       pais genero nivel_previo  \
# 0    Valentina Torres    28            Bogotá   Colombia      F   intermedio
# 1      Carlos Mendoza    34  Ciudad de México     México      M       básico
# 2          Anita Ruiz    25          Medellín   Colombia      F       básico
# 3       Jorge Ramírez    41              Lima       Perú      M     avanzado
# 4        Daniela Soto    29          Santiago      Chile      F   intermedio
# 5       Miguel Flores    37       Guadalajara     México      M       básico
# 6         Laura Gómez    31              Cali   Colombia      F       básico
# 7    Sebastián Castro    26      Buenos Aires  Argentina      M   intermedio
# 8       Camila Vargas    33             Quito    Ecuador      F       básico
# 9      Andrés Herrera    45      Barranquilla   Colombia      M     avanzado
# 10      Paula Jiménez    27        Montevideo    Uruguay      F       básico
# ...

# %% [markdown]
# Pandas → Librerira python
#
# Dataframe → Estructura que crea pandas cuando carga un cvs. Tiene por lo general filas y columnas

# %%
# shape devuelve (fila, columnas)
print(df.shape)

# nombres exactos de las columnas
print(df.columns.tolist())
# Out:
# (25, 14)
# ['nombre', 'edad', 'ciudad', 'pais', 'genero', 'nivel_previo', 'horas_estudio_semana', 'promedio', 'modulos_completados', 'activo', 'fecha_ingreso', 'trabaja_actualmente', 'salario_usd', 'objetivo']

# %%
df["nombre"]
# Out:
# 0      Valentina Torres
# 1        Carlos Mendoza
# 2            Anita Ruiz
# 3         Jorge Ramírez
# 4          Daniela Soto
# 5         Miguel Flores
# 6           Laura Gómez
# 7      Sebastián Castro
# 8         Camila Vargas
# 9        Andrés Herrera
# 10        Paula Jiménez
# 11        Ricardo López
# 12    Isabella Martínez
# 13        Fernando Díaz
# 14       Natalia Romero
# 15        Diego Morales
# 16          Sofía Reyes
# 17      Alejandro Núñez
# 18     Mariana Castillo
# 19           Luis Prada
# 20       Carlos Mendoza
# 21       Andrea Fuentes
# 22        Tomás Aguirre
# 23         Valeria Peña
# 24          José Moreno
# Name: nombre, dtype: str

# %%
df["edad"]
# Out:
# 0     28
# 1     34
# 2     25
# 3     41
# 4     29
# 5     37
# 6     31
# 7     26
# 8     33
# 9     45
# 10    27
# 11    39
# 12    24
# 13    52
# 14    30
# 15    28
# 16    35
# 17    23
# 18    43
# 19    31
# 20    34
# 21    26
# 22    38
# 23    29
# 24    47
# Name: edad, dtype: int64

# %%
print(df.loc[0,"nombre"])
print(df.loc[3,"promedio"])
# Out:
# Valentina Torres
# 7.4

# %%
df.head(10)
# me permite orientarme con respecto a la data que estoy trabajando
# Out:
#              nombre  edad            ciudad       pais genero nivel_previo  \
# 0  Valentina Torres    28            Bogotá   Colombia      F   intermedio
# 1    Carlos Mendoza    34  Ciudad de México     México      M       básico
# 2        Anita Ruiz    25          Medellín   Colombia      F       básico
# 3     Jorge Ramírez    41              Lima       Perú      M     avanzado
# 4      Daniela Soto    29          Santiago      Chile      F   intermedio
# 5     Miguel Flores    37       Guadalajara     México      M       básico
# 6       Laura Gómez    31              Cali   Colombia      F       básico
# 7  Sebastián Castro    26      Buenos Aires  Argentina      M   intermedio
# 8     Camila Vargas    33             Quito    Ecuador      F       básico
# 9    Andrés Herrera    45      Barranquilla   Colombia      M     avanzado
#
#    horas_estudio_semana  promedio  modulos_completados  activo fecha_ingreso  \
# ...

# %% [markdown]
# ver el ultimo nombre
# print(df.loc[df.shape[0] -1, "nombre"])

# %%
print(df.loc[df.shape[0] -1, "nombre"])
# Out:
# Ricardo Rojas

# %%
# Calcula estadissticas importantes
# mean - media
# std - desviación estándar, que tan dispersos est[an los datos. Si es muy alto significa que son muy diferentes los datos
df.describe()
# Out:
#              id       edad  cursos_previos   promedio
# count  20.00000  20.000000       20.000000  20.000000
# mean   10.50000  34.100000        3.100000   6.705000
# std     5.91608   5.901828        2.531902   1.814409
# min     1.00000  27.000000        0.000000   3.700000
# 25%     5.75000  29.000000        1.000000   5.275000
# 50%    10.50000  32.500000        2.500000   6.650000
# 75%    15.25000  40.000000        5.000000   8.225000
# max    20.00000  45.000000        8.000000   9.300000

# %%
# consultar los q tiene promedio mayor de 8 y esten activos
df[(df["promedio"]>=8) & (df["activo"]==True)]
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 4    5      María López    29     Manizales               4       8.8    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True

# %%
#motrar los que tiene promedio superior a 8, con activo true y ordenar por la edad de manera descendente
df[(df['promedio'] >= 8) & (df['activo'] == True)].sort_values(by='edad', ascending=False)
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 4    5      María López    29     Manizales               4       8.8    True

# %% [markdown]
# # Limpiar dataSet pero con criterio

# %% [markdown]
# Detectar → hay algun problema?

# %%
df.isnull().sum()
# Out:
# nombre                  0
# edad                    0
# ciudad                  0
# pais                    0
# genero                  0
# nivel_previo            0
# horas_estudio_semana    0
# promedio                2
# modulos_completados     0
# activo                  0
# fecha_ingreso           0
# trabaja_actualmente     0
# salario_usd             0
# objetivo                0
# dtype: int64
